# %% [markdown]
# <a href="https://colab.research.google.com/github/igorvisconti/rede-basica/blob/main/BigQuery_bquxjob_467f9c9f_1882bca627b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Setup
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

project = 'PROJECT_ID' # Project ID inserted based on the query results selected to explore
location = 'US' # Location inserted based on the query results selected to explore
client = bigquery.Client(project=project, location=location)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %% [markdown]
# ## Reference SQL syntax from the original job
# Use the ```jobs.query```
# [method](https://cloud.google.com/bigquery/docs/reference/rest/v2/jobs/query) to
# return the SQL syntax from the job. This can be copied from the output cell
# below to edit the query now or in the future. Alternatively, you can use
# [this link](https://console.cloud.google.com/bigquery?j=poc-sagis:US:bquxjob_467f9c9f_1882bca627b)
# back to BigQuery to edit the query within the BigQuery user interface.

# %%
# Running this code will display the query used to generate your previous job

job = client.get_job('bquxjob_467f9c9f_1882bca627b') # Job ID inserted based on the query results selected to explore
print(job.query)

# %% [markdown]
# # Result set loaded from BigQuery job as a DataFrame
# Query results are referenced from the Job ID ran from BigQuery and the query
# does not need to be re-run to explore results. The ```to_dataframe```
# [method](https://googleapis.dev/python/bigquery/latest/generated/google.cloud.bigquery.job.QueryJob.html#google.cloud.bigquery.job.QueryJob.to_dataframe)
# downloads the results to a Pandas DataFrame by using the BigQuery Storage API.
#
# To edit query syntax, you can do so from the BigQuery SQL editor or in the
# ```Optional:``` sections below.

# %%
# Running this code will read results from your previous job

job = client.get_job('bquxjob_467f9c9f_1882bca627b') # Job ID inserted based on the query results selected to explore
results = job.to_dataframe()
results
# Out:
#                                                geometry  \
# 0     {'coordinates': [-38.9170028, -3.5174188], 'ty...
# 1     {'coordinates': [-38.0773857, -4.1992003], 'ty...
# 2     {'coordinates': [-37.7021191, -4.5366377], 'ty...
# 3     {'coordinates': [-38.9842067, -3.4452174], 'ty...
# 4     {'coordinates': [-39.6252402, -3.0273976], 'ty...
# ...                                                 ...
# 7703  {'coordinates': [-48.3082246, -10.2028362], 't...
# 7704  {'coordinates': [-48.3095295, -10.2033486], 't...
# 7705  {'coordinates': [-48.3098919, -10.2031193], 't...
# 7706  {'coordinates': [-48.309717, -10.2032179], 'ty...
# 7707  {'coordinates': [-48.30932, -10.2034734], 'typ...
#
#                                              properties     type
# 0     {'layer': 'sub_ENEL_CE SUB', 'DESCR': 'BONS VE...  Feature
# 1     {'layer': 'sub_ENEL_CE SUB', 'DESCR': 'EOLICA ...  Feature
# 2     {'layer': 'sub_ENEL_CE SUB', 'DESCR': 'ROSA DO...  Feature
# ...

# %%
import pandas as pd

query = """
SELECT
  *
FROM
  BDGD21.ARAT
"""
df = pd.read_gbq(query,
                  project_id='PROJECT_ID',
                  dialect='standard') #\,
                  #private_key='trainer/privatekey.json')


#df.properties[0]
#df.geometry[0]
df.head()
# Out:
#                                                  WKT         COD_ID  DIST  \
# 0  MULTIPOLYGON (((-35.5120248692523 -7.498792599...  C.059.PB.2001  6600
# 1  MULTIPOLYGON (((-35.9048474097801 -7.513063418...  C.047.PB.2000  6611
# 2  MULTIPOLYGON (((-49.7346416158178 -28.96205227...  P.019.SC.2008  5372
# 3  MULTIPOLYGON (((-53.274685166687 -26.734804069...  P.022.SC.2008  6897
# 4  MULTIPOLYGON (((-49.9653488200919 -24.23165264...           4248  4248
#
#    FUN_PR  FUN_TE DESCR           layer  \
# 0    1885    1153  None        EPB_ARAT
# 1     205     147  None        EBO_ARAT
# 2      38       0           CEJAMA_ARAT
# 3      75       0           CERACA_ARAT
# 4      18       0        CERAL_DIS_ARAT
#
#                                                 path
# 0  \\10.0.2.75\2021-12-31\EPB_6600_2021-12-31_V10...
# 1  \\10.0.2.75\2021-12-31\EBO_6611_2021-12-31_V10...
# 2  \\10.0.2.75\2021-12-31\CEJAMA_5372_2021-12-31_...
# 3  \\10.0.2.75\2021-12-31\CERACA_6897_2021-12-31_...
# ...

# %% [markdown]
# ## Show descriptive statistics using describe()
# Use the ```pandas DataFrame.describe()```
# [method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)
# to generate descriptive statistics. Descriptive statistics include those that
# summarize the central tendency, dispersion and shape of a dataset’s
# distribution, excluding ```NaN``` values. You may also use other Python methods
# to interact with your data.

# %%
results.describe()
# Out:
#                                                  geometry  \
# count                                                7708
# unique                                               7708
# top     {'coordinates': [-38.9170028, -3.5174188], 'ty...
# freq                                                    1
#
#                                                properties     type
# count                                                7708     7708
# unique                                               7708        1
# top     {'layer': 'sub_ENEL_CE SUB', 'DESCR': 'BONS VE...  Feature
# freq                                                    1     7708
